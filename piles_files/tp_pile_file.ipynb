# %% [markdown]
# # TP Piles/Files
#
# ## 1.1 - Rappels en image
#
# Rappels du fonctionnement de la **pile (stack)** et de la **file (queue)**.
#
# ![Pile/file](https://upload.wikimedia.org/wikipedia/commons/c/c9/QUEUE_VS_STACK.png)
#
#
# ## 1.2 - Pile
#
# !!! question Implémentation d'une pile
# Utiliser le langage orienté objet pour créer une classe `Pile` avec ses méthodes `etre_vide()`, `empiler()`, `depiler()`, `acceder_sommet()` et `calculer_taille()`. Vous utiliserez des objets de type « liste » pour implémenter votre classe `Pile`. Tester votre classe à l’aide de l’exemple proposé dans le cours.
# !!!

# %%
# Votre code

# %% [markdown]
# ## 2.2 - File
#
# !!! question Implémentation d'une file
# Utiliser le langage orienté objet pour créer une classe `File` avec ses méthodes `etre_vide()`, `empiler()`, `depiler()`, `acceder_premier()` et `calculer_taille()`. Vous utiliserez des objets de type « liste » pour implémenter votre classe `File`. Tester votre classe à l’aide de l’exemple proposé dans le cours.
# !!!

# %%
# Votre code

# %% [markdown]
# ## 2.3 - Pour aller plus loin
#
# Nous allons vous proposer ici de reprendre complètement la création de vos classes `Pile` et `File` en n’utilisant plus des objets de type « liste ». Pour cela, nous vous proposons d'utiliser une classe `Noeud` comme ci-dessous.
# ```python
# class Noeud:
#     ''' Mise en place d'une classe Noeud pour ensuite créer
#         les classes agrégats Pile et File
#
#         Chaque noeud contient une information et un pointeur
#         Un objet de la classe noeud possède deux attributs :
#           - un "item" qui contient l'information
#           - une "ref" qui contient éventuellement l'adresse du noeud suivant
#     '''
#     def __init__(self, data):
#         self.item = data  # on affecte une donnée au noeud
#         self.ref = None   # on pointe sur le suivant
#
#     # les getters
#     def get_attributs(self):
#         return self.item, self.ref
#
#     def get_item(self):
#         return self.item
#
#     def get_ref(self):
#         return self.ref
#
#     # les setters
#     def set_item(self, data):
#         self.item = data
#
#     def set_ref(self, ref):
#         self.ref = ref
# ```
#
# Chaque objet de cette classe dispose de deux attributs : un `item` contenant une donnée et une `ref` contenant une adresse mémoire vers laquelle elle pointe (soit un autre objet de type noeud, soit `None`).
#
# !!! question Pile avec classe Noeud
# Reprendre l’implémentation de votre classe `Pile` avec des éléments qui seront des objets de type noeud.
# !!!

# %%
# Votre code

# %% [markdown]
# !!! question File avec classe Noeud
# Reprendre l’implémentation de votre classe `File` avec des éléments qui seront des objets de type `noeud'.
# !!!

# %%
# Votre code
